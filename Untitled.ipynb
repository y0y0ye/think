# %%
import pandas as pd
file_path = 'PSA JAN 2019/demo.csv'

# %%
data = pd.read_csv(file_path, low_memory=False)

# %%
data.columns
# Out:
# Index(['idAnswerSet', 'dateCreated', 'studyId', 'idSubject', 'visit',
#        'VISIT_TYPE', 'DX', 'AGE_OPS', 'AGE_PS', 'AGE_OPSA', 'AGE_PSA',
#        'ARTH_PDX', 'ANT_T', 'ANT_TS', 'ANT_INF', 'ANT_INFS', 'RACE', 'RACE_O',
#        'ETH_MM', 'ETH_MF', 'ETH_FM', 'ETH_FF', 'ETOH_DX', 'ETOH_DXT',
#        'ETOH_DXU', 'ETOH_C', 'ETOH_CT', 'ETOH_CU', 'SMOKE', 'SMOKE_ST',
#        'SMOKE_SP', 'SMOKE_AMT', 'EMP_DX', 'EMP_DXT', 'EMP_DXO', 'EMP_DART',
#        'EMP', 'EMP_O', 'EMP_T', 'EMP_ART', 'EDU_DX', 'EDU', 'MARITAL_DX',
#        'MARITAL_C', 'ADOPT', 'TWIN'],
#       dtype='object')

# %%
data.describe()
# Out:
#          idAnswerSet        studyId     idSubject         visit    VISIT_TYPE  \
# count   19802.000000   19802.000000  19802.000000  19802.000000  18959.000000
# mean   131750.796132    4226.235128  27544.232249     13.745733      0.916082
# std    149884.878267   52579.979926    842.477617     12.238024      0.277272
# min        73.000000       1.000000  26768.000000      1.000000      0.000000
# 25%     37566.250000     356.000000  27116.000000      4.000000      1.000000
# 50%     42516.500000     560.000000  27319.000000     10.000000      1.000000
# 75%    330963.750000    3175.000000  27715.000000     20.000000      1.000000
# max    427607.000000  999999.000000  35031.000000     73.000000      1.000000
#
#            AGE_OPS        AGE_PS     AGE_OPSA       AGE_PSA      ARTH_PDX  \
# count  5950.000000  14469.000000  6600.000000  14556.000000  14552.000000
# mean     25.957395     28.211867    34.975152     36.412888      2.925783
# ...

# %%
pd.concat([data.idAnswerSet,data.dateCreated], axis=1)
# Out:
#        idAnswerSet            dateCreated
# 0            32619  2015-02-02 08:24:16.0
# 1            32620  2015-02-02 08:24:21.0
# 2            32621  2015-02-02 08:24:25.0
# 3            32622  2015-02-02 08:24:31.0
# 4            32623  2015-02-02 08:24:35.0
# 5            32624  2015-02-02 08:24:40.0
# 6            32625  2015-02-02 08:24:46.0
# 7            32626  2015-02-02 08:24:51.0
# 8            32627  2015-02-02 08:24:56.0
# 9            32628  2015-02-02 08:25:02.0
# 10           32629  2015-02-02 08:25:06.0
# 11           32630  2015-02-02 08:25:12.0
# 12           32631  2015-02-02 08:25:16.0
# 13           32632  2015-02-02 08:25:21.0
# 14           32633  2015-02-02 08:25:26.0
# 15           32634  2015-02-02 08:25:30.0
# 16           32635  2015-02-02 08:25:36.0
# 17           32636  2015-02-02 08:25:42.0
# 18          381173  2017-07-13 19:11:22.0
# 19           32637  2015-02-02 08:25:49.0
# 20           32638  2015-02-02 08:25:56.0
# ...
